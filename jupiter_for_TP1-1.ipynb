# %%
import numpy as np
import matplotlib.pyplot as plt
from cmath import sqrt
from random import *
import math

mu, sigma = 11.875,3.61  # mean and standard deviation
features=[3,19,10,15,14,12,9,8,11,12,11,12,13,11,14,16]

# %%
s = np.random.normal(mu, sigma, 1000)

# %%
abs(mu - np.mean(s))
# Out:
# 0.114135945514521

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.11189571545617971

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
np.random.normal(3, 2.5, size=(2, 4))
# Out:
# array([[3.79781778, 8.20902988, 2.54060262, 3.92111295],
#        [4.57052686, 0.05093028, 3.00707009, 4.61577264]])

# %%
#===============================[ la loi Normale ou loi gaussiennes ]============================== 

"""
les deux paramètre de loi normal ou loi gaussiennes sont:
->L'espérance E(X) avec E(X)=Moyenne
->L'écart-type
"""

def loiGaussiennes(features):

#1-Calcul de la moyenne
    
    features_size=len(features)

    sum_xi=0
    
    if features_size > 0 :
        for valeurObservaion in features :
            sum_xi=sum_xi + valeurObservaion

        moyenne=sum_xi/features_size
        print(moyenne)

#2- calcul de la variance
    sum_of_mean_square_deviation=0

    for valeursObservation in features:

        sum_of_mean_square_deviation = sum_of_mean_square_deviation + ((valeursObservation-moyenne)**2)

    variance=(sum_of_mean_square_deviation/features_size)

    print(variance)

#3- L'ecart-type

    std =math.sqrt(variance)

    print(std)

    count, bins, ignored = plt.hist(s, 30, density=True)
    plt.plot(bins, 1/(std * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - moyenne)**2 / (2 * std**2) ),
         linewidth=2, color='r')
plt.show()


  
pass

loiGaussiennes(features)
# Out:
# 11.875
# 12.234375
# 3.4977671449083054

# %%
np.random.normal(11.875,3.61, 16)
# Out:
# array([ 9.91437938, 15.74388244,  8.50606609, 13.38230403, 10.73578543,
#         5.76660975, 18.53236886, 13.09092824, 12.1024084 , 11.76794546,
#         9.50068435, 13.99330373, 11.1237152 , 14.39003014, 13.07812376,
#        12.30078363])

# %%
abs(mu - np.mean(s))
# Out:
# 0.114135945514521

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.11189571545617971

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
def covariance(x, y):

    # Finding the mean of the series x and y
    mean_x = sum(x)/float(len(x))
    mean_y = sum(y)/float(len(y))
    # Subtracting mean from the individual elements
    sub_x = [i - mean_x for i in x]
    sub_y = [i - mean_y for i in y]
    numerator = sum([sub_x[i]*sub_y[i] for i in range(len(sub_x))])
    denominator = len(x)
    cov = numerator/denominator
    return cov

# %%
def calculMoyenne(features) :
    

    features_size=len(features)

    sum_xi=0

    if features_size > 0 :

        for valeurObservaion in features :

            sum_xi=sum_xi + valeurObservaion

        moyenne=sum_xi/features_size

        return moyenne

# %%
def variance(features):

    moyenne=calculMoyenne(features)

    sum_of_mean_square_deviation=0

    features_size=len(features)

    for valeursObservation in features:

        sum_of_mean_square_deviation = sum_of_mean_square_deviation + ((valeursObservation-moyenne)**2)

    variance=(sum_of_mean_square_deviation/features_size)

    return (variance)   
pass

# %%
def LinearRegression1(x,y):

    a=covariance(x,y)/variance(x)
    x=calculMoyenne(x)
    y=calculMoyenne(y)
    b= y-(a*x)
    return (a,b)
pass

# %%
import numpy as np
import matplotlib.pyplot as plt

  
def plot_regression_line(x, y, b):
    # plotting the actual points as scatter plot
    plt.scatter(x, y, color = "m",
               marker = "o", s = 30)
  
    # predicted response vector
    y_pred = b[0] + b[1]*x
  
    # plotting the regression line
    plt.plot(x, y_pred, color = "g")
  
    # putting labels
    plt.xlabel('x')
    plt.ylabel('y')
  
    # function to show plot
    plt.show()
  
def main():
    # observations / data
    array1 = np.array([1,2,3])
    array2 = np.array([2,4,5])
  
    # estimating coefficients
    b = LinearRegression1(array1, array2)
    print("Estimated coefficients:\nb_0 = {}  \
          \nb_1 = {}".format(b[0], b[1]))
  
    # plotting regression line
    plot_regression_line(array1, array2, b)
  
if __name__ == "__main__":
    main()
# Out:
# Estimated coefficients:
# b_0 = 2.25
# b_1 = -0.8333333333333335

# %%
def ObservationsByModality(features):
   
    # initializing the dictionary
    effectif = {}

    for item in features:
         # checking the element in dictionary
            if item in effectif:
                effectif[item] += 1
            else:
                effectif[item] = 1

  #return a dictionary with double input (key : value)
    return effectif
pass

# %%
features=[3,19,10,15,14,12,9,8,11,12,11,12,13,11,14,16]

staffing_dictionary = ObservationsByModality(features)

staffing_dictionary
# Out:
# {3: 1, 19: 1, 10: 1, 15: 1, 14: 2, 12: 3, 9: 1, 8: 1, 11: 3, 13: 1, 16: 1}
